# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://piston-data.mojang.com/v1/objects/8dd1a28015f51b1803213892b50b7b4fc76e594d/server.jar"

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://mohistmc.com/api/v2/projects/mohist/1.20.1/builds/603/mohist-1.20.1-603-server.jar"
    
elif server_type == 'catserver':
    serverURL = "https://jenkins.rbqcloud.cn:30011/job/CatServer-1.18.2/lastSuccessfulBuild/artifact/projects/forge/build/libs/CatServer-1.18.2-3cdd17ea-server.jar"

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist-1.20.1-603-server.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist-1.20.1-603-server.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2enbkFD4TrPjWSUBAESqZIHAITz_6mCXxKH4yhQdmepjmeVQ2" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      help.yml			   server.properties
# banned-players.json  libraries			   spigot.yml
# bukkit.yml	     logs			   usercache.json
# colabconfig.json     mods			   usernamecache.json
# commands.yml	     mohist-1.20.1-603-server.jar  wepif.yml
# config		     mohist-config		   whitelist.json
# crash-reports	     ops.json			   world
# defaultconfigs	     permissions.yml
# eula.txt	     plugins
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 2.tcp.ngrok.io:19571
# Estas jugando a minecraft: mohist en su version: 1.20.1
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
# Thanks for using Mohist - 1.20.1-639, Java(21.0.2) 65.0 PID: 4926
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 655 but you have 639. The latest version has been built on 2024-04-07 10:11:08. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [16:02:56 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.21, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [16:02:56 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [16:02:57 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [16:02:57 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [16:02:58 INFO]: Found 2 dependencies adding them to mods collection
# [16:02:59 INFO]: Compatibility level set to JAVA_17
# [16:02:59 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [16:03:07 INFO]: Mohist mod loading.....
# [16:03:07 INFO]: Forge mod loading, version 47.2.21, for MC 1.20.1 with MCP 20230612.114412
# [16:03:07 INFO]: MinecraftForge v47.2.21 Initialized
# [16:03:07 INFO]: NeoForge v47.2.21 Initialized
# [16:03:07 INFO]: EventDispatcherRegistry initialized
# [16:03:08 INFO]: [voicechat] Compatibility version 18
# [16:03:08 INFO]: [voicechat] Loading plugins
# [16:03:08 INFO]: [voicechat] Loaded 0 plugin(s)
# [16:03:08 INFO]: [voicechat] Initializing plugins
# [16:03:08 INFO]: [voicechat] Initialized 0 plugin(s)
# [16:03:08 INFO]: Got IMC []
# [16:03:09 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [16:03:11 INFO]: Adding datapack listener capsid_recipes
# [16:03:12 INFO]: Loaded 7 recipes
# [16:03:12 INFO]: Loaded 1396 advancements
# [16:03:13 INFO]: Starting minecraft server version 1.20.1
# [16:03:13 INFO]: Loading properties
# [16:03:13 INFO]: Default game type: SURVIVAL
# [16:03:13 INFO]: Generating keypair
# [16:03:13 INFO]: Starting Minecraft server on *:25565
# [16:03:13 INFO]: Using epoll channel type
# [16:03:13 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [16:03:13 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [16:03:13 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [16:03:13 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [16:03:13 INFO]: This server is running Mohist version 1.20.1-639 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.21, NeoForge version 47.1.79)
# [16:03:14 INFO]: Debug logging is enabled
# [16:03:14 INFO]: Server Ping Player Sample Count: 20
# [16:03:14 INFO]: Using 4 threads for Netty based IO
# [16:03:17 INFO]: [WolfyUtilities] Loading 3 libraries... please wait
# [16:03:17 INFO]: [WolfyUtilities] Loading -1 extra libraries... please wait
# [16:03:17 INFO]: [WolfyUtilities] Found libraries libraries/plugins-lib/com/google/inject/guice/5.1.0/guice-5.1.0.jar
# [16:03:17 INFO]: [WolfyUtilities] Found libraries libraries/plugins-lib/it/unimi/dsi/fastutil/8.5.6/fastutil-8.5.6.jar
# [16:03:17 INFO]: [WolfyUtilities] Loaded libraries libraries/plugins-lib/com/google/inject/guice/5.1.0/guice-5.1.0.jar
# [16:03:17 INFO]: [WolfyUtilities] Loaded libraries libraries/plugins-lib/it/unimi/dsi/fastutil/8.5.6/fastutil-8.5.6.jar
# [16:03:19 INFO]: [WolfyUtilities] NMS Version: v1_20_R1
# [16:03:19 INFO]: Reflections took 462 ms to scan 1 urls, producing 915 keys and 3672 values
# [16:03:20 INFO]: [WolfyUtilities] Register Default StackIdentifiers
# [16:03:20 WARN]: [CustomCrafting] Paper not detected! Not using performance improvements.
# [16:03:20 INFO]: [CustomCrafting] NMS Version: v1_20_R1
# [16:03:20 INFO]: [WorldEdit] Loading WorldEdit v7.2.20+6667-f0f1e66
# [16:03:21 INFO]: Got request to register class com.sk89q.worldedit.bukkit.BukkitServerInterface with WorldEdit [com.sk89q.worldedit.extension.platform.PlatformManager@26d98199]
# [16:03:21 INFO]: [SkinsRestorer] Loading SkinsRestorer v15.0.8
# [16:03:21 INFO]: [WorldGuard] Loading WorldGuard v7.0.9+5934e49
# [16:03:21 INFO]: [Permadeath] Loading Permadeath v1.3
# [16:03:22 INFO]: [Shopkeepers] Loading Shopkeepers v2.19.0
# [16:03:23 INFO]: [Shopkeepers] Loaded all plugin classes (942 ms).
# [16:03:23 INFO]: [Shopkeepers] Loading config.
# [16:03:23 WARN]: [Shopkeepers] Config: Forcefully enabled 'disable-inventory-verification' to resolve a known incompatibility with Mohist servers.
# [16:03:23 INFO]: [Shopkeepers] Loading language file: language-en-default.yml
# [16:03:23 INFO]: [Shopkeepers] Registering WorldGuard flag 'allow-shop'.
# [16:03:23 INFO]: [Shopkeepers] Registering defaults.
# [16:03:23 INFO]: [WolfyUtilities] Loading WolfyUtilities v4.16.15.1
# [16:03:23 INFO]: [WolfyUtilities] Register JSON de-/serializers
# [16:03:23 INFO]: [WolfyUtilities] Register JSON Operators
# [16:03:23 INFO]: [WolfyUtilities] Register JSON Value Providers
# [16:03:23 INFO]: [WolfyUtilities] Register CustomItem NBT Checks
# [16:03:23 INFO]: [WolfyUtilities] Register CustomItem Actions
# [16:03:23 INFO]: [WolfyUtilities] Register CustomItem Events
# [16:03:23 INFO]: [WolfyUtilities] Register Particle Animators
# [16:03:23 INFO]: [WolfyUtilities] Register Particle Shapes
# [16:03:23 INFO]: [WolfyUtilities] Register Particle Timers
# [16:03:23 INFO]: [WolfyUtilities] Register Custom Block Data
# [16:03:23 INFO]: [WolfyUtilities] Register Custom Player Data
# [16:03:23 INFO]: [WolfyUtilities] Register NBT Query Nodes
# [16:03:23 INFO]: [CustomCrafting] Loading CustomCrafting v4.16.9.1
# [16:03:23 INFO]: [CustomCrafting] WolfyUtils API: v4.16.15.1
# [16:03:23 INFO]: [CustomCrafting] CustomCrafting: v4.16.9.1
# [16:03:23 INFO]: [CustomCrafting] Environment   : PROD
# [16:03:23 INFO]: [CustomCrafting] Registering CustomItem Data
# [16:03:23 INFO]: [CustomCrafting] Registering Custom Block Data
# [16:03:23 INFO]: [CustomCrafting] Registering Result Extensions
# [16:03:23 INFO]: [CustomCrafting] Registering Result Merge Adapters
# [16:03:23 INFO]: [CustomCrafting] Registering Recipe Conditions
# [16:03:23 INFO]: [CustomCrafting] Registering Recipe Types
# [16:03:23 INFO]: [CustomCrafting] Registering Anvil Recipe Tasks
# [16:03:23 INFO]: [CustomCrafting] Registering Type Registries
# [16:03:23 INFO]: [WorldEdit] Enabling WorldEdit v7.2.20+6667-f0f1e66
# [16:03:23 INFO]: Registering commands with com.sk89q.worldedit.bukkit.BukkitServerInterface
# [16:03:23 INFO]: WEPIF: Using the Bukkit Permissions API.
# [16:03:25 INFO]: Using com.sk89q.worldedit.bukkit.adapter.impl.v1_20_R1.PaperweightAdapter as the Bukkit adapter
# [16:03:27 INFO]: [WorldEdit] ====================================================
# [16:03:27 INFO]: [WorldEdit]  WorldEdit works better if you use Paper
# [16:03:27 INFO]: [WorldEdit]  as your server software.
# [16:03:27 INFO]: [WorldEdit]
# [16:03:27 INFO]: [WorldEdit]  Paper offers significant performance improvements,
# [16:03:27 INFO]: [WorldEdit]  bug fixes, security enhancements and optional
# [16:03:27 INFO]: [WorldEdit]  features for server owners to enhance their server.
# [16:03:27 INFO]: [WorldEdit]
# [16:03:27 INFO]: [WorldEdit]  Paper includes Timings v2, which is significantly
# [16:03:27 INFO]: [WorldEdit]  better at diagnosing lag problems over v1.
# [16:03:27 INFO]: [WorldEdit]
# [16:03:27 INFO]: [WorldEdit]  All of your plugins should still work, and the
# [16:03:27 INFO]: [WorldEdit]  Paper community will gladly help you fix any issues.
# [16:03:27 INFO]: [WorldEdit]
# [16:03:27 INFO]: [WorldEdit]  Join the Paper Community @ https://papermc.io
# [16:03:27 INFO]: [WorldEdit] ====================================================
# [16:03:27 INFO]: [SkinsRestorer] Enabling SkinsRestorer v15.0.8
# [16:03:28 INFO]: [SkinsRestorer] Running on Minecraft 1.20.1.
# [16:03:29 INFO]: [Permadeath] Enabling Permadeath v1.3
# [16:03:29 INFO]: [WolfyUtilities] Enabling WolfyUtilities v4.16.15.1
# [16:03:29 INFO]: [WolfyUtilities] Minecraft version: 1.20.1
# [16:03:29 INFO]: [WolfyUtilities] WolfyUtils version: 4.16.15.1
# [16:03:29 INFO]: [WolfyUtilities] Environment: PROD
# [16:03:29 INFO]: [WolfyUtilities] Loading Plugin integrations:
# [16:03:29 INFO]: [WolfyUtilities]  - No integrations found
# [16:03:29 INFO]: [WolfyUtilities] Register API references
# [16:03:29 INFO]: [WolfyUtilities] Loading stored Custom Items
# [16:03:29 INFO]: [WolfyUtilities] Loading Creative Mode Tabs
# [16:03:29 INFO]: Preparing level "world"
# [16:03:35 INFO]: Preparing start region for dimension minecraft:overworld
# [16:03:36 INFO]: Preparing spawn area: 0%
# [16:03:36 INFO]: Preparing spawn area: 0%
# [16:03:36 INFO]: Preparing spawn area: 0%
# [16:03:36 INFO]: Preparing spawn area: 0%
# [16:03:37 INFO]: Preparing spawn area: 0%
# [16:03:37 INFO]: Preparing spawn area: 0%
# [16:03:38 INFO]: Preparing spawn area: 0%
# [16:03:38 INFO]: Preparing spawn area: 6%
# [16:03:39 INFO]: Preparing spawn area: 9%
# [16:03:39 INFO]: Preparing spawn area: 11%
# [16:03:40 INFO]: Preparing spawn area: 41%
# [16:03:40 INFO]: Time elapsed: 5303 ms
# [16:03:40 INFO]: Preparing start region for dimension minecraft:the_nether
# [16:03:41 INFO]: Preparing spawn area: 0%
# [16:03:41 INFO]: Preparing spawn area: 0%
# [16:03:41 INFO]: Preparing spawn area: 0%
# [16:03:42 INFO]: Preparing spawn area: 7%
# [16:03:42 INFO]: Preparing spawn area: 94%
# [16:03:42 INFO]: Time elapsed: 2018 ms
# [16:03:42 INFO]: Preparing start region for dimension minecraft:the_end
# [16:03:43 INFO]: Preparing spawn area: 0%
# [16:03:43 INFO]: Preparing spawn area: 0%
# [16:03:43 INFO]: Preparing spawn area: 32%
# [16:03:43 INFO]: Time elapsed: 1259 ms
# [16:03:43 INFO]: [WorldGuard] Enabling WorldGuard v7.0.9+5934e49
# [16:03:44 INFO]: [WorldGuard] (world) TNT ignition is PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (world) Lighters are PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (world) Lava fire is PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (world) Fire spread is UNRESTRICTED.
# [16:03:44 INFO]: [WorldGuard] Loaded configuration for world 'world'
# [16:03:44 INFO]: [WorldGuard] (DIM-1) TNT ignition is PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (DIM-1) Lighters are PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (DIM-1) Lava fire is PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (DIM-1) Fire spread is UNRESTRICTED.
# [16:03:44 INFO]: [WorldGuard] Loaded configuration for world 'DIM-1'
# [16:03:44 INFO]: [WorldGuard] (DIM1) TNT ignition is PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (DIM1) Lighters are PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (DIM1) Lava fire is PERMITTED.
# [16:03:44 INFO]: [WorldGuard] (DIM1) Fire spread is UNRESTRICTED.
# [16:03:44 INFO]: [WorldGuard] Loaded configuration for world 'DIM1'
# [16:03:44 INFO]: [WorldGuard] Loading region data...
# [16:03:44 INFO]: [Shopkeepers] Enabling Shopkeepers v2.19.0
# [16:03:44 INFO]: [Shopkeepers] Loading the data of 4 shopkeepers ...
# [16:03:44 INFO]: [CustomCrafting] Enabling CustomCrafting v4.16.9.1
# [16:03:44 INFO]: [CustomCrafting] Loaded fallback language "en_US" v6.1.0 translated by WolfyScript
# [16:03:45 INFO]: [CustomCrafting] Loaded active language "en_US" v6.1.0 translated by WolfyScript
# [16:03:45 INFO]: [CustomCrafting] ____ _  _ ____ ___ ____ _  _ ____ ____ ____ ____ ___ _ _  _ ____
# [16:03:45 INFO]: [CustomCrafting] |    |  | [__   |  |  | |\/| |    |__/ |__| |___  |  | |\ | | __
# [16:03:45 INFO]: [CustomCrafting] |___ |__| ___]  |  |__| |  | |___ |  \ |  | |     |  | | \| |__]
# [16:03:45 INFO]: [CustomCrafting]     Version      | v4.16.9.1
# [16:03:45 INFO]: [CustomCrafting]     WolfyUtils   | v4.16.15.1
# [16:03:45 INFO]: [CustomCrafting]     Bukkit       | 1.20.1-639 (MC: 1.20.1)(API: 1.20.1-R0.1-SNAPSHOT)
# [16:03:45 INFO]: [NBTAPI] Found Spigot: v1_20_R1! Trying to find NMS support
# [16:03:45 INFO]: [NBTAPI] NMS support 'MC1_20_R1' loaded!
# [16:03:45 INFO]: [NBTAPI] Using the plugin 'WolfyUtilities' to create a bStats instance!
# [16:03:45 INFO]: [CustomCrafting]
# [16:03:45 INFO]: [CustomCrafting] Special thanks to my Patrons for supporting this project:
# [16:03:45 INFO]: [CustomCrafting] Omarlatif, Nat R, Obsidian_Sword, LiveJunye, Mithran, Teddy
# [16:03:45 INFO]: [CustomCrafting] Invictus_Vulpes , Luuk Musch, fioxu, JorshStark, Perny Dev, Charlie
# [16:03:45 INFO]: [CustomCrafting] iachen, whja t, Green Masks, lance fector, Jack Snellings, MineHouse Server
# [16:03:45 INFO]: [CustomCrafting] ------------------------------------------------------------------------
# [16:03:45 INFO]: [CustomCrafting] Data destination: LOCAL
# [16:03:45 INFO]: [CustomCrafting] Initiating Inventory GUIs
# [16:03:45 INFO]: [CustomCrafting] Register ItemCreator Tabs
# [16:03:45 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [16:03:46 INFO]: [CustomCrafting] Loading Recipes & Items
# [16:03:46 INFO]: [CustomCrafting] - - - - [Local Storage] - - - -
# [16:03:46 INFO]: [CustomCrafting] [LOCAL] Using 4 threads
# [16:03:46 INFO]: [CustomCrafting] [LOCAL] Looking through data folder...
# [16:03:46 INFO]: [CustomCrafting] [LOCAL] Loading Items
# [16:03:46 INFO]: [CustomCrafting] [LOCAL] Loading Recipes
# [16:03:46 ERROR]: Could not find parent org/bukkit/inventory/CraftingRecipe for class org/bukkit/inventory/ShapedRecipe in classloader jdk.internal.loader.ClassLoaders$AppClassLoader@4f2410ac on thread Thread[#84,ForkJoinPool-3-worker-2,5,SERVER]
# [16:03:46 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: org.bukkit.inventory.CraftingRecipe
# 	at jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[?:?]
# 	at jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[?:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:580) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass0(PluginClassLoader.java:143) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass(PluginClassLoader.java:138) ~[?:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.Class.forName0(Native Method) ~[?:?]
# 	at java.lang.Class.forName(Class.java:534) ~[?:?]
# 	at java.lang.Class.forName(Class.java:513) ~[?:?]
# 	at sun.reflect.generics.factory.CoreReflectionFactory.makeNamedType(CoreReflectionFactory.java:114) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.visitClassTypeSignature(Reifier.java:125) ~[?:?]
# 	at sun.reflect.generics.tree.ClassTypeSignature.accept(ClassTypeSignature.java:49) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.reifyTypeArguments(Reifier.java:68) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.visitClassTypeSignature(Reifier.java:138) ~[?:?]
# 	at sun.reflect.generics.tree.ClassTypeSignature.accept(ClassTypeSignature.java:49) ~[?:?]
# 	at sun.reflect.generics.repository.ClassRepository.computeSuperInterfaces(ClassRepository.java:117) ~[?:?]
# 	at sun.reflect.generics.repository.ClassRepository.getSuperInterfaces(ClassRepository.java:95) ~[?:?]
# 	at java.lang.Class.getGenericInterfaces(Class.java:1296) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.util.ClassUtil.getGenericInterfaces(ClassUtil.java:1310) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory._resolveSuperInterfaces(TypeFactory.java:1521) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory._fromClass(TypeFactory.java:1476) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory.constructSpecializedType(TypeFactory.java:488) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.DeserializationContext.constructSpecializedType(DeserializationContext.java:303) ~[?:?]
# 	at me.wolfyscript.customcrafting.recipes.RecipeTypeIdResolver.typeFromId(RecipeTypeIdResolver.java:66) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.TypeDeserializerBase._findDeserializer(TypeDeserializerBase.java:159) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.AsPropertyTypeDeserializer._deserializeTypedForId(AsPropertyTypeDeserializer.java:125) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.AsPropertyTypeDeserializer.deserializeTypedFromObject(AsPropertyTypeDeserializer.java:110) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.AbstractDeserializer.deserializeWithType(AbstractDeserializer.java:263) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.impl.TypeWrappedDeserializer.deserialize(TypeWrappedDeserializer.java:74) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.DefaultDeserializationContext.readRootValue(DefaultDeserializationContext.java:323) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.ObjectReader._bindAndClose(ObjectReader.java:2051) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.ObjectReader.readValue(ObjectReader.java:1599) ~[?:?]
# 	at me.wolfyscript.customcrafting.handlers.LocalStorageLoader$NewDataLoader.lambda$loadRecipesInNamespace$2(LocalStorageLoader.java:483) ~[?:?]
# 	at java.util.concurrent.ForkJoinTask$RunnableExecuteAction.exec(ForkJoinTask.java:1423) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# [16:03:46 ERROR]: Could not find parent org/bukkit/inventory/CraftingRecipe for class org/bukkit/inventory/ShapelessRecipe in classloader jdk.internal.loader.ClassLoaders$AppClassLoader@4f2410ac on thread Thread[#83,ForkJoinPool-3-worker-1,5,SERVER]
# [16:03:46 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: org.bukkit.inventory.CraftingRecipe
# 	at jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[?:?]
# 	at jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[?:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:580) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass0(PluginClassLoader.java:143) ~[?:?]
# 	at org.bukkit.plugin.java.PluginClassLoader.loadClass(PluginClassLoader.java:138) ~[?:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.Class.forName0(Native Method) ~[?:?]
# 	at java.lang.Class.forName(Class.java:534) ~[?:?]
# 	at java.lang.Class.forName(Class.java:513) ~[?:?]
# 	at sun.reflect.generics.factory.CoreReflectionFactory.makeNamedType(CoreReflectionFactory.java:114) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.visitClassTypeSignature(Reifier.java:125) ~[?:?]
# 	at sun.reflect.generics.tree.ClassTypeSignature.accept(ClassTypeSignature.java:49) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.reifyTypeArguments(Reifier.java:68) ~[?:?]
# 	at sun.reflect.generics.visitor.Reifier.visitClassTypeSignature(Reifier.java:138) ~[?:?]
# 	at sun.reflect.generics.tree.ClassTypeSignature.accept(ClassTypeSignature.java:49) ~[?:?]
# 	at sun.reflect.generics.repository.ClassRepository.computeSuperInterfaces(ClassRepository.java:117) ~[?:?]
# 	at sun.reflect.generics.repository.ClassRepository.getSuperInterfaces(ClassRepository.java:95) ~[?:?]
# 	at java.lang.Class.getGenericInterfaces(Class.java:1296) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.util.ClassUtil.getGenericInterfaces(ClassUtil.java:1310) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory._resolveSuperInterfaces(TypeFactory.java:1521) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory._fromClass(TypeFactory.java:1476) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.type.TypeFactory.constructSpecializedType(TypeFactory.java:488) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.DeserializationContext.constructSpecializedType(DeserializationContext.java:303) ~[?:?]
# 	at me.wolfyscript.customcrafting.recipes.RecipeTypeIdResolver.typeFromId(RecipeTypeIdResolver.java:66) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.TypeDeserializerBase._findDeserializer(TypeDeserializerBase.java:159) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.AsPropertyTypeDeserializer._deserializeTypedForId(AsPropertyTypeDeserializer.java:125) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.jsontype.impl.AsPropertyTypeDeserializer.deserializeTypedFromObject(AsPropertyTypeDeserializer.java:110) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.AbstractDeserializer.deserializeWithType(AbstractDeserializer.java:263) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.impl.TypeWrappedDeserializer.deserialize(TypeWrappedDeserializer.java:74) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.deser.DefaultDeserializationContext.readRootValue(DefaultDeserializationContext.java:323) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.ObjectReader._bindAndClose(ObjectReader.java:2051) ~[?:?]
# 	at me.wolfyscript.lib.com.fasterxml.jackson.databind.ObjectReader.readValue(ObjectReader.java:1599) ~[?:?]
# 	at me.wolfyscript.customcrafting.handlers.LocalStorageLoader$NewDataLoader.lambda$loadRecipesInNamespace$2(LocalStorageLoader.java:483) ~[?:?]
# 	at java.util.concurrent.ForkJoinTask$RunnableExecuteAction.exec(ForkJoinTask.java:1423) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# [16:03:46 INFO]: [CustomCrafting] [LOCAL] Loaded 6 recipes in 104ms
# [16:03:46 INFO]: [CustomCrafting] Indexing Recipe Book...
# [16:03:46 INFO]: [CustomCrafting] Indexed Recipe Book!
# [16:03:46 INFO]: [CustomCrafting] ------------------------------------------------------------------------
# [16:03:46 INFO]: [Mohist] Enabling Mohist v1.20.1
# [16:03:46 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [16:03:46 INFO]: Done (16.715s)! For help, type "help"
# [16:03:46 INFO]: Successfully initialized permission handler forge:default_handler
# [16:03:46 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [16:03:46 WARN]: [voicechat] Running in offline mode - Voice chat encryption is not secure!
# [16:03:46 INFO]: [voicechat] Voice chat server started at port 25565
# [16:03:46 INFO]: GlitchWorld ➤ No se ha encontrado una librería JDA, deberás instalar una en caso de querer utilizar un bot de Discord.
# [16:03:46 INFO]: Descarga aquí: https://www.spigotmc.org/resources/permadeath-%E2%98%A0%EF%B8%8F.112343/
# [16:03:46 INFO]: Si no puedes descargarlo allí, únete a este Discord y te daremos acceso al enlace: https://discord.gg/8evPbuxPke
# [16:03:46 INFO]: [08/04/2024] 16:03:46 [ERROR] Error al cargar el mundo del end, esto hará que el end no funcione como debe.
#
# [16:03:46 INFO]: [08/04/2024] 16:03:46 [ERROR] Abre el archivo config.yml y establece el mundo del end en la opción: EndWorld
#
# [16:03:46 INFO]: [08/04/2024] 16:03:46 [INFO] El plugin utilizará el mundo DIM1 como mundo del End.
#
# [16:03:46 INFO]: ------------------------------------------
# [16:03:46 INFO]:              PERMADEATH
# [16:03:46 INFO]:      - Versión: 1.3
# [16:03:46 INFO]:      - Versión del Servidor: v1.20
# [16:03:46 INFO]: ------------------------------------------
# [16:03:46 INFO]:  >> INFORME DE ESTADO
# [16:03:46 INFO]: > Estado de mundos: Overworld: world End: world
# [16:03:46 INFO]:     > End: world
# [16:03:46 INFO]:     > Overworld: world
# [16:03:46 INFO]: > Estado de Compatibilidad: Compatible
# [16:03:46 INFO]: > Software: SpigotMC (Compatible)
# [16:03:46 INFO]: > Cambios:
# [16:03:46 INFO]: >   Días disponibles: 1-60
# [16:03:46 INFO]: [SkinsRestorer] ----------------------------------------------
# [16:03:46 INFO]: [SkinsRestorer]     +==================+
# [16:03:46 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [16:03:46 INFO]: [SkinsRestorer]     |------------------|
# [16:03:46 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [16:03:46 INFO]: [SkinsRestorer]     +==================+
# [16:03:46 INFO]: [SkinsRestorer] ----------------------------------------------
# [16:03:46 INFO]: [SkinsRestorer]     Version: 15.0.8
# [16:03:46 INFO]: [SkinsRestorer]     Commit: 8b54a2c
# [16:03:46 INFO]: [SkinsRestorer]     This is the latest version!
# [16:03:46 INFO]: [SkinsRestorer] ----------------------------------------------
# [16:03:47 INFO]: GlitchWorld ➤ Versión del plugin: Versión más reciente instalada.
# [16:04:09 INFO]: Mr_PanckeisXD se ha unido al glitch.
# [16:04:09 INFO]: Mr_PanckeisXD[/127.0.0.1:55918] logged in with entity id 87 at ([world]0.5, 55.0, 0.5)
# [16:04:10 INFO]: [voicechat] Received secret request of [ADMIN] Mr_PanckeisXD (18)
# [16:04:10 INFO]: [voicechat] Sent secret to [ADMIN] Mr_PanckeisXD
# [16:07:39 INFO]: ivelich350 se ha unido al glitch.
# [16:07:39 INFO]: ivelich350[/127.0.0.1:36284] logged in with entity id 377 at ([world]9920.300000011921, 128.92795994226054, 9993.35641471201)
# [16:07:40 INFO]: [voicechat] Received secret request of [ADMIN] ivelich350 (18)
# [16:07:40 INFO]: [voicechat] Sent secret to [ADMIN] ivelich350
# [16:07:43 INFO]: ivelich350 issued server command: /gamemode survival
# [16:07:43 INFO]: [[ADMIN] ivelich350: Set own game mode to Survival Mode]
# [16:07:44 INFO]: ivelich350 issued server command: /gamemode spectator
# [16:07:44 INFO]: [[ADMIN] ivelich350: Set own game mode to Spectator Mode]
# [16:07:48 INFO]: ivelich350 issued server command: /gamemode survival
# [16:07:48 INFO]: [[ADMIN] ivelich350: Set own game mode to Survival Mode]
# [16:07:49 INFO]: ivelich350 issued server command: /gamemode creative
# [16:07:49 INFO]: [[ADMIN] ivelich350: Set own game mode to Creative Mode]
# [16:08:30 INFO]: ivelich350 issued server command: //set air
# [16:08:57 INFO]: ivelich350 issued server command: //stack 77
# [16:09:05 INFO]: ivelich350 issued server command: //undo
# [16:09:22 INFO]: ivelich350 issued server command: //stack me 77
# [16:09:40 INFO]: ivelich350 issued server command: //stack north
# [16:09:47 INFO]: ivelich350 issued server command: //undo
# [16:09:53 INFO]: ivelich350 issued server command: //stack north 77
# [16:09:57 INFO]: ivelich350 issued server command: //stack north
# [16:09:59 INFO]: ivelich350 issued server command: //undo
# [16:11:06 ERROR]: Invalid entity rotation: NaN, discarding.
# [16:11:28 INFO]: ivelich350 issued server command: //copy
# [16:11:32 INFO]: ivelich350 issued server command: //paste
# [16:11:46 INFO]: ivelich350 issued server command: //undo
# [16:11:51 INFO]: ivelich350 issued server command: //set air
# [16:12:08 INFO]: Mr_PanckeisXD issued server command: //set 0
# [16:12:10 INFO]: Mr_PanckeisXD issued server command: //undo
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [16:13:03 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,nether_bricks
# [16:13:34 INFO]: ivelich350 issued server command: //set air
# [16:13:39 INFO]: ivelich350 issued server command: //undo
# [16:13:58 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,nether_bricks
# [16:14:07 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [16:14:07 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [16:14:13 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,nether_bricks
# [16:14:15 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [16:14:15 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [16:14:20 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,nether_bricks
# [16:14:33 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,45%nether_bricks
# [16:14:37 INFO]: ivelich350 issued server command: //undo
# [16:14:38 INFO]: ivelich350 issued server command: //undo
# [16:14:40 INFO]: ivelich350 issued server command: //undo
# [16:14:41 INFO]: ivelich350 issued server command: //undo
# [16:14:59 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,45%nether_bricks
# [16:15:04 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,45%nether_bricks
# [16:15:12 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,45%nether_bricks
# [16:15:17 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,45%nether_bricks
# [16:15:25 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,45%nether_bricks
# [16:15:33 INFO]: ivelich350 issued server command: //set 1%magma_block,9%cracked_nether_bricks,45%red_nether_bricks,45%nether_bricks
# [16:16:01 INFO]: ivelich350 issued server command: //set 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# [16:16:10 INFO]: ivelich350 issued server command: //set 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# [16:16:13 INFO]: ivelich350 issued server command: //set 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# [16:16:20 INFO]: ivelich350 issued server command: //set 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# [16:16:20 INFO]: ivelich350 issued server command: /gamemode survival
# [16:16:20 INFO]: [[ADMIN] ivelich350: Set own game mode to Survival Mode]
# [16:16:22 INFO]: ivelich350 issued server command: /gamemode spectator
# [16:16:22 INFO]: [[ADMIN] ivelich350: Set own game mode to Spectator Mode]
# [16:16:23 INFO]: ivelich350 issued server command: /gamemode survival
# [16:16:23 INFO]: [[ADMIN] ivelich350: Set own game mode to Survival Mode]
# [16:16:25 INFO]: Mr_PanckeisXD issued server command: /effect give Mr_PanckeisXD minecraft:strength 10000 255 true
# [16:16:25 INFO]: [[ADMIN] Mr_PanckeisXD: Applied effect Strength to [ADMIN] Mr_PanckeisXD]
# [16:16:25 INFO]: ivelich350 issued server command: /gamemode creative
# [16:16:25 INFO]: [[ADMIN] ivelich350: Set own game mode to Creative Mode]
# [16:16:32 INFO]: ivelich350 issued server command: //set 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# [16:16:35 INFO]: ivelich350 issued server command: //set 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# [16:16:37 INFO]: Mr_PanckeisXD issued server command: /effect give Mr_PanckeisXD minecraft:resistance 10000 255 true
# [16:16:37 INFO]: [[ADMIN] Mr_PanckeisXD: Applied effect Resistance to [ADMIN] Mr_PanckeisXD]
# [16:16:38 INFO]: Mr_PanckeisXD issued server command: /gamemode survival
# [16:16:38 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Survival Mode]
# [16:16:38 INFO]: ivelich350 issued server command: /gamemode spectator
# [16:16:38 INFO]: [[ADMIN] ivelich350: Set own game mode to Spectator Mode]
# [16:16:41 INFO]: [INFO] La probabilidad del tótem se encuentra desactivada para el día: 2
# [16:16:41 INFO]: ivelich350 issued server command: /gamemode creative
# [16:16:41 INFO]: [[ADMIN] ivelich350: Set own game mode to Creative Mode]
# [16:16:45 INFO]: Set the weather to rain & thunder
# [16:16:45 INFO]: Mr_PanckeisXD ha muerto y ahora descanza en paz.
# [16:16:45 INFO]: Este es el comienzo del sufrimiento eterno de Mr_PanckeisXD. ¡HA SIDO GLITCHEADO!
# [16:16:45 INFO]: X: -6 || Y: 53 || Z: 5
# [16:16:45 INFO]: [ADMIN] Mr_PanckeisXD was slain by Zombie
# [16:16:50 INFO]: ¡Comienza el GLITCH Train con duración de 2 horas!
# [16:16:55 INFO]: Mr_PanckeisXD issued server command: /gamemode creative
# [16:16:55 INFO]: [[ADMIN] Mr_PanckeisXD: Set own game mode to Creative Mode]
# [16:17:03 INFO]: ivelich350 issued server command: //hsphere 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# [16:17:19 INFO]: ivelich350 issued server command: //hsphere 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks 40 10
# [16:17:26 INFO]: ivelich350 issued server command: //hsphere 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks 10 40
# [16:17:50 INFO]: ivelich350 issued server command: //hsphere 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# [16:18:21 INFO]: ivelich350 issued server command: //hsphere 1%magma_block,45%cracked_nether_bricks,9%red_nether_bricks,45%nether_bricks
# >
